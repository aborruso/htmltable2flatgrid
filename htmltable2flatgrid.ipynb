# %%
import os
import requests
import urllib
import math
import copy
import pandas as pd	
import numpy as np
from bs4 import BeautifulSoup

# %%
class html_tables(object):
    
    def __init__(self, url):
        
        self.url      = url
        self.r        = requests.get(self.url)
        self.url_soup = BeautifulSoup(self.r.text)
        
    def read(self):
        
        self.tables      = []
        self.tables_html = self.url_soup.find_all("table")
        
        # Parse each table
        for n in range(0, len(self.tables_html)):
            
            n_cols = 0
            n_rows = 0
            
            for row in self.tables_html[n].find_all("tr"):
                col_tags = row.find_all(["td", "th"])
                if len(col_tags) > 0:
                    n_rows += 1
                    if len(col_tags) > n_cols:
                        n_cols = len(col_tags)
            
            # Create dataframe
            df = pd.DataFrame(index = range(0, n_rows), columns = range(0, n_cols))
            
            # Create list to store rowspan values 
            skip_index = [0 for i in range(0, n_cols)]

            # Start by iterating over each row in this table...
            row_counter = 0
            for row in self.tables_html[n].find_all("tr"):
                
                # Skip row if it's blank
                if len(row.find_all(["td", "th"])) == 0:
                    next
                
                else:
                    
                    # Get all cells containing data in this row
                    columns = row.find_all(["td", "th"])
                    col_dim = []
                    row_dim = []
                    col_dim_counter = -1
                    row_dim_counter = -1
                    col_counter = -1
                    this_skip_index = copy.deepcopy(skip_index)
                    
                    for col in columns:
                        
                        # Determine cell dimensions
                        colspan = col.get("colspan")
                        if colspan is None:
                            col_dim.append(1)
                        else:
                            col_dim.append(int(colspan))
                        col_dim_counter += 1
                            
                        rowspan = col.get("rowspan")
                        if rowspan is None:
                            row_dim.append(1)
                        else:
                            row_dim.append(int(rowspan))
                        row_dim_counter += 1
                            
                        # Adjust column counter
                        if col_counter == -1:
                            col_counter = 0  
                        else:
                            col_counter = col_counter + col_dim[col_dim_counter - 1]
                            
                        while skip_index[col_counter] > 0:
                            col_counter += 1

                        # Get cell contents  
                        cell_data = col.get_text()
                        
                        # Insert data into cell
                        df.iat[row_counter, col_counter] = cell_data

                        # Record column skipping index
                        if row_dim[row_dim_counter] > 1:
                            this_skip_index[col_counter] = row_dim[row_dim_counter]
                
                # Adjust row counter 
                row_counter += 1
                
                # Adjust column skipping index
                skip_index = [i - 1 if i > 0 else i for i in this_skip_index]

            # Append dataframe to list of tables
            self.tables.append(df)
        
        return(self.tables)

# %%
wiki_url = "https://it.wikipedia.org/wiki/Leone_d%27oro_al_miglior_film"
wiki = html_tables(wiki_url)
wiki_table = wiki.read()[2]
wiki_table
# Out:
#               0                                                  1  \
# 0        Anno\n                                             Film\n
# 1        1946\n                  L'uomo del Sud (The Southerner)\n
# 2        1947\n                                  Sirena (Siréna)\n
# 3        1948\n                                  Amleto (Hamlet)\n
# 4        1949\n                                            Manon\n
# 5        1950\n            Giustizia è fatta (Justice est faite)\n
# 6        1951\n                              Rashomon (Rashômon)\n
# 7        1952\n                 Giochi proibiti (Jeux interdits)\n
# 8        1953\n              Il Leone d'oro non venne assegnato.\n
# 9        1954\n                                Giulietta e Romeo\n
# 10       1955\n                        Ordet - La parola (Ordet)\n
# 11       1956\n              Il Leone d'oro non venne assegnato.\n
# 12       1957\n                                        Aparajito\n
# 13       1958\n           L'uomo del risciò (Muhomatsu No Issho)\n
# 14       1959\n                                 La grande guerra\n
# 15          NaN                         Il generale Della Rovere\n
# 16       1960\n       Il passaggio del Reno (Le passage du Rhin)\n
# 17       1961\n  L'anno scorso a Marienbad (L'année dernière à ...
# 18       1962\n                                Cronaca familiare\n
# 19          NaN              L'infanzia di Ivan (Ivanovo Detsvo)\n
# 20       1963\n                              Le mani sulla città\n
# 21       1964\n                                    Deserto rosso\n
# 22       1965\n                        Vaghe stelle dell'Orsa...\n
# 23       1966\n                           La battaglia di Algeri\n
# 24       1967\n                  Bella di giorno (Belle de jour)\n
# 25       1968\n  Artisti sotto la tenda del circo: perplessi (D...
# 26  1969-1972\n                    La mostra non fu competitiva.\n
# 27       1973\n                    La mostra non fu organizzata.\n
# 28  1974-1976\n  La mostra non fu organizzata: vi fu una sezion...
# 29  1977-1978\n  La mostra non fu organizzata: vi furono due re...
# ..          ...                                                ...
# 43       1991\n                 Urga - Territorio d'amore (Urga)\n
# 44       1992\n           La storia di Qiu Ju (Qui Ju da guansi)\n
# 45       1993\n                        America oggi (Short Cuts)\n
# 46          NaN     Tre colori - Film blu (Trois couleurs: Bleu)\n
# 47       1994\n                     Vive L'Amour (Aiqing Wansui)\n
# 48          NaN                Prima della pioggia (Pred doždot)\n
# 49       1995\n                                  Cyclo (Xich-lo)\n
# 50       1996\n                                  Michael Collins\n
# 51       1997\n               Hana-bi - Fiori di fuoco (Hana-bi)\n
# 52       1998\n                                    Così ridevano\n
# 53       1999\n         Non uno di meno (Yi ge dou bu neng shao)\n
# 54       2000\n                             Il cerchio (Dayereh)\n
# 55       2001\n  Monsoon Wedding - Matrimonio indiano (Monsoon ...
# 56       2002\n                Magdalene (The Magdalene Sisters)\n
# 57       2003\n                        Il ritorno (Vozvrašcenje)\n
# 58       2004\n            Il segreto di Vera Drake (Vera Drake)\n
# 59       2005\n  I segreti di Brokeback Mountain (Brokeback Mou...
# 60       2006\n                       Still Life (Sanxia haoren)\n
# 61       2007\n      Lussuria - Seduzione e tradimento (Se, jie)\n
# 62       2008\n                                     The Wrestler\n
# 63       2009\n                                          Lebanon\n
# 64       2010\n                                        Somewhere\n
# 65       2011\n                                            Faust\n
# 66       2012\n                                    Pietà (Pieta)\n
# 67       2013\n                                        Sacro GRA\n
# 68       2014\n  Un piccione seduto su un ramo riflette sull'es...
# 69       2015\n                           Ti guardo (Desde allá)\n
# 70       2016\n  The Woman Who Left - La donna che se ne è anda...
# 71       2017\n  La forma dell'acqua - The Shape of Water (The ...
# 72       2018\n                                             Roma\n
#
#                            2                             3
# 0                  Regista\n                     Nazione\n
# 1              Jean Renoir\n                 Stati Uniti\n
# 2             Karel Steklý\n              Cecoslovacchia\n
# 3         Laurence Olivier\n                 Regno Unito\n
# 4    Henri-Georges Clouzot\n                     Francia\n
# 5            André Cayatte\n                     Francia\n
# 6           Akira Kurosawa\n                    Giappone\n
# 7             René Clément\n                     Francia\n
# 8                        NaN                           NaN
# 9        Renato Castellani\n                      Italia\n
# 10     Carl Theodor Dreyer\n                   Danimarca\n
# 11                       NaN                           NaN
# 12            Satyajit Ray\n                       India\n
# 13         Hiroshi Inagaki\n                    Giappone\n
# 14         Mario Monicelli\n                      Italia\n
# 15      Roberto Rossellini\n                      Italia\n
# 16           André Cayatte\n                     Francia\n
# 17           Alain Resnais\n                     Francia\n
# 18         Valerio Zurlini\n                      Italia\n
# 19       Andrej Tarkovskij\n                        URSS\n
# 20          Francesco Rosi\n                      Italia\n
# 21  Michelangelo Antonioni\n                      Italia\n
# 22        Luchino Visconti\n                      Italia\n
# 23        Gillo Pontecorvo\n             Italia/ Algeria\n
# 24             Luis Buñuel\n                     Francia\n
# 25         Alexander Kluge\n              Germania Ovest\n
# 26                       NaN                           NaN
# 27                       NaN                           NaN
# 28                       NaN                           NaN
# 29                       NaN                           NaN
# ..                       ...                           ...
# 43        Nikita Mikhalkov\n                        URSS\n
# 44             Zhang Yimou\n                        Cina\n
# 45           Robert Altman\n                 Stati Uniti\n
# 46    Krzysztof Kieślowski\n            Francia/ Polonia\n
# 47         Tsai Ming-liang\n                      Taiwan\n
# 48         Milčo Mančevski\n                   Macedonia\n
# 49           Tran Anh Hung\n                     Vietnam\n
# 50             Neil Jordan\n                 Regno Unito\n
# 51          Takeshi Kitano\n                    Giappone\n
# 52           Gianni Amelio\n                      Italia\n
# 53             Zhang Yimou\n                        Cina\n
# 54            Jafar Panahi\n                        Iran\n
# 55               Mira Nair\n                       India\n
# 56            Peter Mullan\n                     Irlanda\n
# 57      Andrei Zviagintsev\n                      Russia\n
# 58              Mike Leigh\n                 Regno Unito\n
# 59                 Ang Lee\n                 Stati Uniti\n
# 60             Jia Zhangke\n                        Cina\n
# 61                 Ang Lee\n   Stati Uniti/ Cina/ Taiwan\n
# 62        Darren Aronofsky\n                 Stati Uniti\n
# 63             Samuel Maoz\n                     Israele\n
# 64           Sofia Coppola\n                 Stati Uniti\n
# 65       Aleksandr Sokurov\n                      Russia\n
# 66              Kim Ki-duk\n               Corea del Sud\n
# 67         Gianfranco Rosi\n                      Italia\n
# 68           Roy Andersson\n                      Svezia\n
# 69           Lorenzo Vigas\n                   Venezuela\n
# 70                Lav Diaz\n                   Filippine\n
# 71      Guillermo del Toro\n                 Stati Uniti\n
# 72          Alfonso Cuarón\n                     Messico\n
#
# [73 rows x 4 columns]
